# %% [markdown]
# 1 Part I: the perceptron (20 points)
# In this first task you’re asked to implement and test a simple artificial neuron: a perceptron (see perceptron-
# slides.pdf ).

# %% [markdown]
# ### 1.1 Task 1
#
# Generate a dataset of points in R2. To do this, define two Gaussian distributions and sample 100 points from each.
#
# Your dataset should then contain a total of 200 points, 100 from each distribution. Keep 80 points per distribution
#
# as the training (160 in total), 20 for the test (40 in total).

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# ---------- 1. 完全随机地生成两个高斯参数 ----------
rng = np.random.default_rng(400)          # 可设 seed 复现

def make_random_gaussian_2d(
        n_per_class=100,
        test_size=0.2,
        seed=400,
        mu1=None,
        Sig1=None,
        mu2=None,
        Sig2=None,
        return_params=False):
    
    rng = np.random.default_rng(seed)

    # --- 均值 ---
    mu1 = np.asarray(mu1) if mu1 is not None else rng.uniform(-4, 4, size=2)
    mu2 = np.asarray(mu2) if mu2 is not None else rng.uniform(-4, 4, size=2)

    # --- 协方差 ---
    def _rand_cov():
        eig = rng.uniform(0.3, 1.5, size=2)
        theta = rng.uniform(0, 2*np.pi)
        rot = np.array([[np.cos(theta), -np.sin(theta)],
                        [np.sin(theta),  np.cos(theta)]])
        return rot @ np.diag(eig) @ rot.T

    Sig1 = np.asarray(Sig1) if Sig1 is not None else _rand_cov()
    Sig2 = np.asarray(Sig2) if Sig2 is not None else _rand_cov()
    print("Gaussian 1: 均值 =", mu1, ", 协方差 =\n", Sig1)
    print("Gaussian 2: 均值 =", mu2, ", 协方差 =\n", Sig2)

    # --- 采样 ---
    X1 = rng.multivariate_normal(mu1, Sig1, size=n_per_class)
    X2 = rng.multivariate_normal(mu2, Sig2, size=n_per_class)
    y1 = np.full(n_per_class, -1)
    y2 = np.full(n_per_class,  1)

    X = np.vstack((X1, X2))
    y = np.hstack((y1, y2))

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=42, stratify=y)

    if return_params:
        return (X_train, X_test, y_train, y_test), (mu1, Sig1, mu2, Sig2)
    return X_train, X_test, y_train, y_test

# ---------- 3. 划分 ----------
X_train, X_test, y_train, y_test = make_random_gaussian_2d(test_size=0.2, seed=400)


print(f"Train data shape: {X_train.shape}, Train labels shape: {y_train.shape}"
      f"\nTest data shape: {X_test.shape}, Test labels shape: {y_test.shape}")

# ---------- 4. 可视化（三类子图） ----------
fig, ax = plt.subplots(1, 3, figsize=(18, 5))

# ---- 子图 1：类别 -1 的 train/test ----
mask0_tr = (y_train == -1)
mask0_te = (y_test == -1)
ax[0].scatter(X_train[mask0_tr, 0], X_train[mask0_tr, 1],
              color='tab:blue', marker='o', label='Class-0 Train')
ax[0].scatter(X_test[mask0_te, 0], X_test[mask0_te, 1],
              color='tab:blue', marker='x', s=60, label='Class-0 Test')
ax[0].set_title('Class -1  (80 train / 20 test)')
ax[0].legend()
ax[0].axis('equal')

# ---- 子图 2：类别 1 的 train/test ----
mask1_tr = (y_train == 1)
mask1_te = (y_test == 1)
ax[1].scatter(X_train[mask1_tr, 0], X_train[mask1_tr, 1],
              color='tab:red', marker='o', label='Class-1 Train')
ax[1].scatter(X_test[mask1_te, 0], X_test[mask1_te, 1],
              color='tab:red', marker='x', s=60, label='Class-1 Test')
ax[1].set_title('Class 1  (80 train / 20 test)')
ax[1].legend()
ax[1].axis('equal')

# ---- 子图 3：总览 ----
ax[2].scatter(X_train[:, 0], X_train[:, 1], c=y_train,
              cmap='coolwarm', marker='o', label='Train')
ax[2].scatter(X_test[:, 0], X_test[:, 1], c=y_test,
              cmap='coolwarm', marker='x', s=60, label='Test')
ax[2].set_title('Both classes  (160 train / 40 test)')
ax[2].legend()
ax[2].axis('equal')

plt.tight_layout()
plt.show()
# Out:
# Gaussian 1: 均值 = [-2.40720951  0.8947924 ] , 协方差 =
#  [[ 0.6597315  -0.0840578 ]
#  [-0.0840578   0.52924502]]
# Gaussian 2: 均值 = [ 3.81821381 -0.94685265] , 协方差 =
#  [[ 0.88397507 -0.25307314]
#  [-0.25307314  1.15603701]]
# Train data shape: (160, 2), Train labels shape: (160,)
# Test data shape: (40, 2), Test labels shape: (40,)

# %% [markdown]
# ### 1.2 Task 2
#
# Implement the perceptron following the specs in perceptron.py and the pseudocode in perceptronslides.pdf.

# %%
class Perceptron(object):

    def __init__(self, n_inputs, max_epochs=100, learning_rate=0.01):
        self.n_inputs = n_inputs  # Fill in: Initialize number of inputs
        self.max_epochs = max_epochs  # Fill in: Initialize maximum number of epochs
        self.learning_rate = learning_rate  # Fill in: Initialize learning rate
        self.weights = np.zeros(n_inputs + 1)  # Fill in: Initialize weights with zeros (including bias)(最后一项为偏执项)
    def print_info(self):
        print(f"n_inputs: {self.n_inputs}, max_epochs: {self.max_epochs}, learning_rate: {self.learning_rate}, weights: {self.weights}")
            
        
    def forward(self, input_vec):
       """
        Predicts label from input.
        f(x) = sign(w·x + b)
        Args:
            input_vec (np.ndarray): Input array of training data, input vec must be all samples
        Returns:
            int: Predicted label (1 or -1) or Predicted lables.
        """
       dot_product = input_vec @ self.weights[:-1] + self.weights[-1]  # (n,)
       return np.where(dot_product >= 0, 1, -1)       # 批量预测
        
    def train(self, training_inputs, labels):
        for i in range(self.max_epochs): 
            predictions = self.forward(training_inputs)  # (n,)
            miss_indices = (predictions != labels)  # (n,)
            accuracy = np.mean(predictions == labels)
            # 计算权重更新
            weight_gradient = -(labels[miss_indices] @ training_inputs[miss_indices])
            bias_gradient = -np.sum(labels[miss_indices])
            # 更新权重和偏置
            self.weights[:-1] -= self.learning_rate * weight_gradient
            self.weights[-1]  -= self.learning_rate * bias_gradient
            if i < 10:
                print(f"Epoch {i}: Accuracy = {accuracy*100:.2f}%, Misclassified samples = {np.sum(miss_indices)}")
                print("weight_gradient:", weight_gradient, "bias_gradient:", bias_gradient)
                print("Updated weights:", self.weights)

# %% [markdown]
# ### 1.3 Task 3
#
# Train the perceptron on the training data (160 points) and test in on the remaining 40 test points. Compute the
# classification accuracy on the test set.

# %%
p = Perceptron(n_inputs=2, max_epochs=100, learning_rate=0.01)
print(X_train.shape, y_train.shape)
p.train(X_train, y_train)
y_pred = p.forward(X_test)
acc = np.mean(y_pred == y_test)
print(f"Test accuracy: {acc:.2%}")
# Out:
# (160, 2) (160,)
# Epoch 0: Accuracy = 50.00%, Misclassified samples = 80
# weight_gradient: [-187.44412256   71.78377004] bias_gradient: 80
# Updated weights: [ 1.87444123 -0.7178377  -0.8       ]
# Epoch 1: Accuracy = 100.00%, Misclassified samples = 0
# weight_gradient: [-0. -0.] bias_gradient: 0
# Updated weights: [ 1.87444123 -0.7178377  -0.8       ]
# Epoch 2: Accuracy = 100.00%, Misclassified samples = 0
# weight_gradient: [-0. -0.] bias_gradient: 0
# Updated weights: [ 1.87444123 -0.7178377  -0.8       ]
# Epoch 3: Accuracy = 100.00%, Misclassified samples = 0
# weight_gradient: [-0. -0.] bias_gradient: 0
# Updated weights: [ 1.87444123 -0.7178377  -0.8       ]
# Epoch 4: Accuracy = 100.00%, Misclassified samples = 0
# weight_gradient: [-0. -0.] bias_gradient: 0
# Updated weights: [ 1.87444123 -0.7178377  -0.8       ]
# Epoch 5: Accuracy = 100.00%, Misclassified samples = 0
# weight_gradient: [-0. -0.] bias_gradient: 0
# Updated weights: [ 1.87444123 -0.7178377  -0.8       ]
# ...

# %% [markdown]
# ### 1.4 Task 4
# Experiment with different sets of points (generated as described in Task 1). What happens during the training if
# the means of the two Gaussians are too close and/or if their variance is too high?

# %%
def experiment(name, mu1, mu2, Sig1, Sig2, n=200, seed=42, lr=0.01, max_ep=100):
    """训练 + 绘图 + 打印准确率"""
    X_tr, X_te, y_tr, y_te = make_random_gaussian_2d(n_per_class=100, seed=seed,
                                mu1=mu1, mu2=mu2, Sig1=Sig1, Sig2=Sig2,
                                return_params=False)

    model = Perceptron(n_inputs=2, max_epochs=max_ep, learning_rate=lr)
    model.train(X_tr, y_tr)
    acc = np.mean(model.forward(X_te) == y_te)

    print(f"{name}  测试准确率:{acc:.1%}  迭代:{max_ep} 次")

    # ------ 画图 ------
    plt.figure(figsize=(5, 4))
    plot_2d_split(X_tr, y_tr, model, title=name)
    plt.show()

def plot_2d_split(X, y, model, title="", h=0.02):
    """画散点 + 决策边界"""
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    mesh = np.c_[xx.ravel(), yy.ravel()]
    Z = model.forward(mesh)
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.25, cmap='coolwarm')
    plt.scatter(X[:, 0], X[:, 1], c=y, s=20, cmap='coolwarm', edgecolors='k')
    plt.title(title)
    plt.axis('equal')

# %%
# ---------- 训练感知器 ----------
# ① 正常情况
experiment("Normal", mu1=[-3, 0], mu2=[3, 0],Sig1=[[1, 0], [0, 1]],Sig2=[[1, 0], [0, 1]])

# ② 均值过近
experiment("Means too close", mu1=[0, 0], mu2=[0.3, 0.3],Sig1=[[0.3, 0], [0, 0.3]],Sig2=[[0.3, 0], [0, 0.3]])

# ③ 方差过大
experiment("High variance", mu1=[-3, 0], mu2=[3, 0],Sig1=[[100, 0], [0, 100]],Sig2=[[100, 0], [0, 100]])
# Out:
# Gaussian 1: 均值 = [-3  0] , 协方差 =
#  [[1 0]
#  [0 1]]
# Gaussian 2: 均值 = [3 0] , 协方差 =
#  [[1 0]
#  [0 1]]
# Epoch 0: Accuracy = 50.00%, Misclassified samples = 80
# weight_gradient: [-237.96315392   -7.93509348] bias_gradient: 80
# Updated weights: [ 2.37963154  0.07935093 -0.8       ]
# Epoch 1: Accuracy = 100.00%, Misclassified samples = 0
# weight_gradient: [-0. -0.] bias_gradient: 0
# Updated weights: [ 2.37963154  0.07935093 -0.8       ]
# Epoch 2: Accuracy = 100.00%, Misclassified samples = 0
# weight_gradient: [-0. -0.] bias_gradient: 0
# Updated weights: [ 2.37963154  0.07935093 -0.8       ]
# Epoch 3: Accuracy = 100.00%, Misclassified samples = 0
# weight_gradient: [-0. -0.] bias_gradient: 0
# Updated weights: [ 2.37963154  0.07935093 -0.8       ]
# Epoch 4: Accuracy = 100.00%, Misclassified samples = 0
# weight_gradient: [-0. -0.] bias_gradient: 0
# Updated weights: [ 2.37963154  0.07935093 -0.8       ]
# Epoch 5: Accuracy = 100.00%, Misclassified samples = 0
# ...

# %% [markdown]
# 实验小结
#
# | 组别 | 均值间距 | 协方差 | 迭代次数 | 测试准确率 |
# |----|--------|----------|--------|----------|
# | 1. Normal | (-3,0) vs (3,0) | 0.5I | 100 | 100 % |
# | 2. Close | (0,0) vs (0.3,0.3) | 0.3I | 100 | 57.5 % |
# | 3. Large Var | (-3,0) vs (3,0) | 100I | 100 | 67.5 % |
#
# ---
#
# **现象分析**
#
# 1. 第一组收敛迅速，3 个 epoch 就 100 %。  原因：两类中心远、方差小，能画一条直线分开。
#
# 2. 第二组均值只差 0.4，两类云几乎叠在一起，直线躲不开错分点，权重一直在小范围抖动。
#
# 3. 第三组介于中间。中心虽然隔得远，但方差太大，点云互相渗透，边界两边全是杂点，准确率 65 % 左右。
#
# ---
#
# **总结**
# 感知器是“只要线性可分就能收敛”。
# - 中心太近 → 不可分；
# - 方差太大 → 局部重叠不可分。
