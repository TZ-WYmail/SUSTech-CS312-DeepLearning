# %% [markdown]
# ### 2.1 Task 1
# Implement the MLP architecture by completing the files mlp numpy.py and modules.py.

# %%
import numpy as np

class Linear(object):
    def __init__(self, in_features, out_features):
        self.in_features = in_features
        self.out_features = out_features
        self.cache = None
        self.params['weight'] = np.random.normal(loc=0.0, scale = 0.5, size = (in_features,out_features))
        self.params['bias'] = np.zeros((1,out_features))
        self.grads = {'weight': None, 'bias': None}

    def forward(self, x):
        print('Linear forward:', x.shape, self.params['weight'].shape, self.params['bias'].shape)
        self.cache = x
        output = x @ self.params['weight'] + self.params['bias']
        return output

    def backward(self, dout):
        x = self.cache
        self.grads['weight'] = x.T @ dout
        self.grads['bias'] = np.sum(dout, axis=0)
        dx = dout @ self.params['weight'].T
        return dx
        
class ReLU(object):
    def __init__(self):
        self.cache = None

    def forward(self, x):
        self.cache = x
        return np.maximum(0, x)

    def backward(self, dout):
        dx = dout.copy()
        dx[self.cache <= 0] = 0
        return dx

class SoftMax(object):
    def __init__(self):
        self.cache = None
        
    def forward(self, x):
        shifted_x = x - np.max(x, axis=1, keepdims=True)  # 数值稳定性
        exp_x = np.exp(shifted_x)
        probs = exp_x / np.sum(exp_x, axis=1, keepdims=True)
        self.cache = probs
        return probs

    def backward(self, dout):
        return dout

class CrossEntropy(object):
    def __init__(self):
        self.cache = None

    def forward(self, x, y):
        N = x.shape[0]
        # --- 手动实现数值稳定性 ---
        max_x = np.max(x, axis=1)
        max_x_reshaped = max_x.reshape(-1, 1)
        exp_x = np.exp(x - max_x_reshaped)
        sum_exp_x = np.sum(exp_x, axis=1)
        sum_exp_x_reshaped = sum_exp_x.reshape(-1, 1)
        probs = exp_x / sum_exp_x_reshaped
        self.cache = probs
        
        # 计算交叉熵损失
        log_probs = np.log(probs[range(N), y] + 1e-12)  # 添加小量防止log(0)
        loss = -np.mean(log_probs)
        
        return loss

    def backward(self, x, y):
        N = x.shape[0]
        probs = self.cache
        dx = probs.copy()
        dx[range(N), y] -= 1
        dx /= N
        return dx

# %%
class MLP(object):
    def __init__(self, n_inputs, n_hidden, n_classes):
        dims = [n_inputs] + n_hidden + [n_classes]
        self.layers = []
        for i in range(len(dims) - 1):
            self.layers.append(Linear(dims[i], dims[i + 1]))
            if i < len(dims) - 2:
                self.layers.append(ReLU())
        
    def forward(self, x):
        out = x
        for layer in self.layers:
            out = layer.forward(out)
        return out

    def backward(self, dout):
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

# %% [markdown]
# ### 2.2 Task 2
# Implement training and testing script in train mlp numpy.py. (Please keep 80% of the dataset for training and
# the remaining 20% for testing. Note that this is a random split of 80% and 20% )

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

sample = make_moons(n_samples=1000, shuffle=True, noise=0.1, random_state=42)
data = sample[0]
label = sample[1]

train_X = np.mat(data[0:800])
train_y = label[0:800].astype(int)  # <--- 确保是整数类型
test_X = np.mat(data[800:])
test_y = label[800:].astype(int)    # <--- 确保是整数类型

# 创建可视化
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Plot 1: Complete dataset
axes[0].scatter(data[:, 0], data[:, 1], c=label, cmap='viridis', alpha=0.7, s=30)
axes[0].set_title('Complete Dataset (n=1000)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Feature 1')
axes[0].set_ylabel('Feature 2')
axes[0].grid(True, alpha=0.3)

# Plot 2: Training data
axes[1].scatter(train_X[:, 0].A1, train_X[:, 1].A1, c=train_y, 
                cmap='viridis', alpha=0.7, s=30)
axes[1].set_title('Training Data (n=800)', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Feature 1')
axes[1].set_ylabel('Feature 2')
axes[1].grid(True, alpha=0.3)

# Plot 3: Test data
axes[2].scatter(test_X[:, 0].A1, test_X[:, 1].A1, c=test_y, 
                cmap='viridis', alpha=0.7, s=30)
axes[2].set_title('Test Data (n=200)', fontsize=14, fontweight='bold')
axes[2].set_xlabel('Feature 1')
axes[2].set_ylabel('Feature 2')
axes[2].grid(True, alpha=0.3)

plt.suptitle('Part II: Make Moons Dataset (Using Integer Labels)', 
             fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3 Task 3
# Using the default values of the parameters, report the results of your experiments using a jupyter notebook where
# you show the accuracy curves for both training and test data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from mlp_numpy import MLP

def accuracy(predictions, targets):
     # 将概率分布转换为预测标签
    predicted_labels = np.argmax(predictions, axis=1)
    result = predicted_labels == targets
    accuracy = np.mean(result)
    return accuracy

def generate_data(num):
    data, label = make_moons(n_samples=num, shuffle=True, noise=0.1, random_state=42)
    
    split_idx = int(num * 0.8)
    
    train_X = data[:split_idx]
    train_y = label[:split_idx].astype(int)
    
    test_X = data[split_idx:]
    test_y = label[split_idx:].astype(int)
    
    return train_X, train_y, test_X, test_y

def train_BGD(dnn_hidden_units, learning_rate, max_steps, eval_freq):
    train_X, train_y, test_X, test_y = generate_data(1000)
    model = MLP(n_inputs=2, n_hidden=dnn_hidden_units, n_classes=2)
    loss_fn = CrossEntropy()

    history = {'train_loss': [], 'train_acc': [], 'test_loss': [], 'test_acc': []}
    num_samples = train_X.shape[0]

    for step in range(max_steps):
        # 1. 前向：全量样本
        scores = model.forward(train_X)
        loss = loss_fn.forward(scores, train_y)

        # 2. 反向：全量梯度
        dout = loss_fn.backward(scores, train_y)
        model.backward(dout)

        # 3. 更新参数
        for layer in model.layers:
            if layer.__class__.__name__ == 'Linear':
                layer.params['weight'] -= learning_rate * layer.grads['weight']
                layer.params['bias'] -= learning_rate * layer.grads['bias']

        # 4. 记录
        history['train_loss'].append(loss)
        if step % eval_freq == 0 or step == max_steps - 1:
            train_acc = accuracy(scores, train_y)
            test_scores = model.forward(test_X)
            test_loss = loss_fn.forward(test_scores, test_y)
            test_acc = accuracy(test_scores, test_y)
            history['train_acc'].append(train_acc)
            history['test_loss'].append(test_loss)
            history['test_acc'].append(test_acc)
            print(f"BGD Step: {step:4d} | Train Loss: {loss:.4f} | "
                  f"Train Acc: {train_acc:.2f}% | Test Loss: {test_loss:.4f} | "
                  f"Test Acc: {test_acc:.2f}%")
    return history,model


def train_SGD(dnn_hidden_units, learning_rate, max_steps, eval_freq):
    train_X, train_y, test_X, test_y = generate_data(1000)
    model = MLP(n_inputs=2, n_hidden=dnn_hidden_units, n_classes=2)
    loss_fn = CrossEntropy()

    history = {'train_loss': [], 'train_acc': [], 'test_loss': [], 'test_acc': []}
    num_samples = train_X.shape[0]

    for step in range(max_steps):
        idx = np.random.randint(0, num_samples)
        x_i = train_X[idx:idx+1]
        y_i = train_y[idx:idx+1]

        score_i = model.forward(x_i)
        loss_i = loss_fn.forward(score_i, y_i)
        dout = loss_fn.backward(score_i, y_i)
        model.backward(dout)
        for layer in model.layers:
            if layer.__class__.__name__ == 'Linear':
                layer.params['weight'] -= learning_rate * layer.grads['weight']
                layer.params['bias'] -= learning_rate * layer.grads['bias']

        history['train_loss'].append(loss_i)
        if step % eval_freq == 0 or step == max_steps - 1:
            train_scores = model.forward(train_X)
            train_acc = accuracy(train_scores, train_y)
            test_scores = model.forward(test_X)
            test_loss = loss_fn.forward(test_scores, test_y)
            test_acc = accuracy(test_scores, test_y)
            history['train_acc'].append(train_acc)
            history['test_loss'].append(test_loss)
            history['test_acc'].append(test_acc)
            print(f"SGD Step: {step:4d} | Train Loss: {loss_i:.4f} | "
                  f"Train Acc: {train_acc:.2f}% | Test Loss: {test_loss:.4f} | "
                  f"Test Acc: {test_acc:.2f}%")
    return history,model

def plot_curves(history, eval_freq, title_suffix=""):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

    # 绘制损失曲线
    ax1.plot(history['train_loss'], 'b-', linewidth=2, label='Train Loss')
    # 使用传入的 eval_freq 参数
    test_loss_steps = np.arange(0, len(history['test_loss']) * eval_freq, eval_freq)
    ax1.plot(test_loss_steps, history['test_loss'], 'r-o', label='Test Loss')
    ax1.set_title(f'Loss Curves {title_suffix}', fontsize=16)
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.grid(True, linestyle='--', alpha=0.6)

    # 绘制准确率曲线
    # 使用传入的 eval_freq 参数
    train_acc_steps = np.arange(0, len(history['train_acc']) * eval_freq, eval_freq)
    test_acc_steps = np.arange(0, len(history['test_acc']) * eval_freq, eval_freq)
    ax2.plot(train_acc_steps, history['train_acc'], 'g-', linewidth=2, label='Train Accuracy')
    ax2.plot(test_acc_steps, history['test_acc'], 'm--', linewidth=2, label='Test Accuracy')
    ax2.set_title(f'Accuracy Curves {title_suffix}', fontsize=16)
    ax2.set_xlabel('Step (Epoch)')
    ax2.set_ylabel('Accuracy (%)')
    ax2.legend()
    ax2.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.show()
def plot_decision_boundary(model, title_suffix=""):
# 生成网格
    x_min, x_max = -2, 3
    y_min, y_max = -1.5, 2
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 500),
                            np.linspace(y_min, y_max, 500))
    grid = np.c_[xx.ravel(), yy.ravel()]

    # 模型预测
    probs = model.forward(grid)
    Z = np.argmax(probs, axis=1).reshape(xx.shape)

    # 绘图
    plt.figure(figsize=(6, 5))
    plt.contourf(xx, yy, Z, levels=50, cmap=plt.cm.RdBu, alpha=0.8)
    plt.colorbar(label='predict class')

    # 再画一遍数据点
    train_X, train_y, _, _ = generate_data(1000)
    plt.scatter(train_X[:, 0], train_X[:, 1], c=train_y, cmap=plt.cm.RdBu, edgecolors='k')
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)
    plt.title(f"Decision Boundary {title_suffix}")
    plt.xlabel("Feature 1")
    plt.ylabel("Feature 2")
    plt.tight_layout()
    plt.show()

# %%
# 设置超参数
HIDDEN_UNITS = [64, 32]  
LEARNING_RATE = 0.01     
MAX_STEPS = 1000      
EVAL_FREQ = 20

# 1. 批量梯度下降
history_bgd,model = train_BGD(HIDDEN_UNITS, LEARNING_RATE, MAX_STEPS, EVAL_FREQ)
plot_curves(history_bgd, EVAL_FREQ, title_suffix="(BGD)")
plot_decision_boundary(model, title_suffix="(BGD)")

# 2. 随机梯度下降
history_sgd,model = train_SGD(HIDDEN_UNITS, LEARNING_RATE, MAX_STEPS, EVAL_FREQ)
plot_curves(history_sgd, EVAL_FREQ, title_suffix="(SGD)")
plot_decision_boundary(model, title_suffix="(SGD)")
# Out:
# Initialized MLP with layers:
#   Layer 1: Linear(2 -> 64)
#     Activation: ReLU
#   Layer 2: Linear(64 -> 32)
#     Activation: ReLU
#   Layer 3: Linear(32 -> 2)
# BGD Step:    0 | Train Loss: 1.1693 | Train Acc: 0.54% | Test Loss: 1.1082 | Test Acc: 0.51%
# BGD Step:   20 | Train Loss: 0.3326 | Train Acc: 0.85% | Test Loss: 0.3570 | Test Acc: 0.82%
# BGD Step:   40 | Train Loss: 0.2911 | Train Acc: 0.87% | Test Loss: 0.3113 | Test Acc: 0.83%
# BGD Step:   60 | Train Loss: 0.2693 | Train Acc: 0.88% | Test Loss: 0.2891 | Test Acc: 0.85%
# BGD Step:   80 | Train Loss: 0.2541 | Train Acc: 0.88% | Test Loss: 0.2744 | Test Acc: 0.86%
# BGD Step:  100 | Train Loss: 0.2416 | Train Acc: 0.88% | Test Loss: 0.2629 | Test Acc: 0.86%
# BGD Step:  120 | Train Loss: 0.2308 | Train Acc: 0.88% | Test Loss: 0.2526 | Test Acc: 0.86%
# BGD Step:  140 | Train Loss: 0.2214 | Train Acc: 0.88% | Test Loss: 0.2439 | Test Acc: 0.86%
# BGD Step:  160 | Train Loss: 0.2134 | Train Acc: 0.88% | Test Loss: 0.2366 | Test Acc: 0.86%
# BGD Step:  180 | Train Loss: 0.2067 | Train Acc: 0.88% | Test Loss: 0.2304 | Test Acc: 0.88%
# BGD Step:  200 | Train Loss: 0.2007 | Train Acc: 0.89% | Test Loss: 0.2249 | Test Acc: 0.90%
# BGD Step:  220 | Train Loss: 0.1954 | Train Acc: 0.90% | Test Loss: 0.2202 | Test Acc: 0.90%
# BGD Step:  240 | Train Loss: 0.1905 | Train Acc: 0.90% | Test Loss: 0.2157 | Test Acc: 0.90%
# BGD Step:  260 | Train Loss: 0.1860 | Train Acc: 0.91% | Test Loss: 0.2114 | Test Acc: 0.90%
# BGD Step:  280 | Train Loss: 0.1817 | Train Acc: 0.91% | Test Loss: 0.2073 | Test Acc: 0.92%
# BGD Step:  300 | Train Loss: 0.1775 | Train Acc: 0.92% | Test Loss: 0.2032 | Test Acc: 0.93%
# BGD Step:  320 | Train Loss: 0.1736 | Train Acc: 0.92% | Test Loss: 0.1993 | Test Acc: 0.93%
# BGD Step:  340 | Train Loss: 0.1698 | Train Acc: 0.93% | Test Loss: 0.1953 | Test Acc: 0.94%
# BGD Step:  360 | Train Loss: 0.1660 | Train Acc: 0.93% | Test Loss: 0.1913 | Test Acc: 0.94%
# BGD Step:  380 | Train Loss: 0.1623 | Train Acc: 0.93% | Test Loss: 0.1873 | Test Acc: 0.94%
# BGD Step:  400 | Train Loss: 0.1587 | Train Acc: 0.94% | Test Loss: 0.1834 | Test Acc: 0.94%
# BGD Step:  420 | Train Loss: 0.1551 | Train Acc: 0.94% | Test Loss: 0.1795 | Test Acc: 0.94%
# BGD Step:  440 | Train Loss: 0.1516 | Train Acc: 0.94% | Test Loss: 0.1757 | Test Acc: 0.94%
# BGD Step:  460 | Train Loss: 0.1482 | Train Acc: 0.94% | Test Loss: 0.1720 | Test Acc: 0.94%
# BGD Step:  480 | Train Loss: 0.1447 | Train Acc: 0.95% | Test Loss: 0.1683 | Test Acc: 0.94%
# BGD Step:  500 | Train Loss: 0.1413 | Train Acc: 0.95% | Test Loss: 0.1646 | Test Acc: 0.94%
# BGD Step:  520 | Train Loss: 0.1378 | Train Acc: 0.95% | Test Loss: 0.1609 | Test Acc: 0.94%
# BGD Step:  540 | Train Loss: 0.1344 | Train Acc: 0.95% | Test Loss: 0.1572 | Test Acc: 0.94%
# BGD Step:  560 | Train Loss: 0.1310 | Train Acc: 0.96% | Test Loss: 0.1537 | Test Acc: 0.94%
# BGD Step:  580 | Train Loss: 0.1277 | Train Acc: 0.96% | Test Loss: 0.1502 | Test Acc: 0.95%
# BGD Step:  600 | Train Loss: 0.1245 | Train Acc: 0.96% | Test Loss: 0.1468 | Test Acc: 0.95%
# BGD Step:  620 | Train Loss: 0.1214 | Train Acc: 0.96% | Test Loss: 0.1437 | Test Acc: 0.95%
# BGD Step:  640 | Train Loss: 0.1183 | Train Acc: 0.96% | Test Loss: 0.1406 | Test Acc: 0.95%
# BGD Step:  660 | Train Loss: 0.1154 | Train Acc: 0.96% | Test Loss: 0.1376 | Test Acc: 0.95%
# BGD Step:  680 | Train Loss: 0.1125 | Train Acc: 0.96% | Test Loss: 0.1347 | Test Acc: 0.95%
# BGD Step:  700 | Train Loss: 0.1097 | Train Acc: 0.96% | Test Loss: 0.1319 | Test Acc: 0.96%
# BGD Step:  720 | Train Loss: 0.1070 | Train Acc: 0.96% | Test Loss: 0.1292 | Test Acc: 0.96%
# BGD Step:  740 | Train Loss: 0.1044 | Train Acc: 0.97% | Test Loss: 0.1264 | Test Acc: 0.97%
# BGD Step:  760 | Train Loss: 0.1018 | Train Acc: 0.97% | Test Loss: 0.1238 | Test Acc: 0.97%
# BGD Step:  780 | Train Loss: 0.0993 | Train Acc: 0.97% | Test Loss: 0.1213 | Test Acc: 0.97%
# BGD Step:  800 | Train Loss: 0.0968 | Train Acc: 0.97% | Test Loss: 0.1187 | Test Acc: 0.97%
# BGD Step:  820 | Train Loss: 0.0944 | Train Acc: 0.97% | Test Loss: 0.1163 | Test Acc: 0.97%
# BGD Step:  840 | Train Loss: 0.0920 | Train Acc: 0.97% | Test Loss: 0.1138 | Test Acc: 0.97%
# BGD Step:  860 | Train Loss: 0.0897 | Train Acc: 0.97% | Test Loss: 0.1114 | Test Acc: 0.97%
# BGD Step:  880 | Train Loss: 0.0874 | Train Acc: 0.97% | Test Loss: 0.1092 | Test Acc: 0.97%
# BGD Step:  900 | Train Loss: 0.0852 | Train Acc: 0.97% | Test Loss: 0.1069 | Test Acc: 0.97%
# BGD Step:  920 | Train Loss: 0.0831 | Train Acc: 0.97% | Test Loss: 0.1048 | Test Acc: 0.97%
# BGD Step:  940 | Train Loss: 0.0811 | Train Acc: 0.97% | Test Loss: 0.1027 | Test Acc: 0.97%
# BGD Step:  960 | Train Loss: 0.0791 | Train Acc: 0.97% | Test Loss: 0.1006 | Test Acc: 0.97%
# BGD Step:  980 | Train Loss: 0.0772 | Train Acc: 0.98% | Test Loss: 0.0987 | Test Acc: 0.97%
# BGD Step:  999 | Train Loss: 0.0755 | Train Acc: 0.98% | Test Loss: 0.0968 | Test Acc: 0.97%
# Initialized MLP with layers:
#   Layer 1: Linear(2 -> 64)
#     Activation: ReLU
#   Layer 2: Linear(64 -> 32)
#     Activation: ReLU
#   Layer 3: Linear(32 -> 2)
# SGD Step:    0 | Train Loss: 3.3106 | Train Acc: 0.74% | Test Loss: 0.5255 | Test Acc: 0.75%
# SGD Step:   20 | Train Loss: 0.1978 | Train Acc: 0.77% | Test Loss: 0.4653 | Test Acc: 0.76%
# SGD Step:   40 | Train Loss: 0.2975 | Train Acc: 0.85% | Test Loss: 0.2863 | Test Acc: 0.85%
# SGD Step:   60 | Train Loss: 0.0487 | Train Acc: 0.85% | Test Loss: 0.2681 | Test Acc: 0.85%
# SGD Step:   80 | Train Loss: 0.0548 | Train Acc: 0.93% | Test Loss: 0.2434 | Test Acc: 0.93%
# SGD Step:  100 | Train Loss: 0.8860 | Train Acc: 0.90% | Test Loss: 0.2182 | Test Acc: 0.92%
# SGD Step:  120 | Train Loss: 0.0031 | Train Acc: 0.92% | Test Loss: 0.2050 | Test Acc: 0.93%
# SGD Step:  140 | Train Loss: 0.0170 | Train Acc: 0.89% | Test Loss: 0.2471 | Test Acc: 0.92%
# SGD Step:  160 | Train Loss: 0.0430 | Train Acc: 0.93% | Test Loss: 0.2784 | Test Acc: 0.92%
# SGD Step:  180 | Train Loss: 0.0267 | Train Acc: 0.90% | Test Loss: 0.2066 | Test Acc: 0.90%
# SGD Step:  200 | Train Loss: 0.0072 | Train Acc: 0.89% | Test Loss: 0.2530 | Test Acc: 0.90%
# SGD Step:  220 | Train Loss: 1.9673 | Train Acc: 0.93% | Test Loss: 0.2224 | Test Acc: 0.92%
# SGD Step:  240 | Train Loss: 0.0223 | Train Acc: 0.88% | Test Loss: 0.2313 | Test Acc: 0.89%
# SGD Step:  260 | Train Loss: 0.0148 | Train Acc: 0.91% | Test Loss: 0.1819 | Test Acc: 0.92%
# SGD Step:  280 | Train Loss: 0.0190 | Train Acc: 0.92% | Test Loss: 0.2287 | Test Acc: 0.91%
# SGD Step:  300 | Train Loss: 0.0062 | Train Acc: 0.92% | Test Loss: 0.2712 | Test Acc: 0.91%
# SGD Step:  320 | Train Loss: 0.5512 | Train Acc: 0.93% | Test Loss: 0.2207 | Test Acc: 0.92%
# SGD Step:  340 | Train Loss: 0.0374 | Train Acc: 0.94% | Test Loss: 0.1809 | Test Acc: 0.93%
# SGD Step:  360 | Train Loss: 0.0101 | Train Acc: 0.93% | Test Loss: 0.1810 | Test Acc: 0.93%
# SGD Step:  380 | Train Loss: 0.0203 | Train Acc: 0.94% | Test Loss: 0.1623 | Test Acc: 0.93%
# SGD Step:  400 | Train Loss: 0.0312 | Train Acc: 0.94% | Test Loss: 0.1530 | Test Acc: 0.94%
# SGD Step:  420 | Train Loss: 0.5423 | Train Acc: 0.94% | Test Loss: 0.1738 | Test Acc: 0.94%
# SGD Step:  440 | Train Loss: 1.6376 | Train Acc: 0.93% | Test Loss: 0.1656 | Test Acc: 0.93%
# SGD Step:  460 | Train Loss: 0.6015 | Train Acc: 0.95% | Test Loss: 0.1776 | Test Acc: 0.94%
# SGD Step:  480 | Train Loss: 0.0053 | Train Acc: 0.96% | Test Loss: 0.1276 | Test Acc: 0.95%
# SGD Step:  500 | Train Loss: 0.0170 | Train Acc: 0.97% | Test Loss: 0.1206 | Test Acc: 0.96%
# SGD Step:  520 | Train Loss: 0.0131 | Train Acc: 0.96% | Test Loss: 0.1273 | Test Acc: 0.94%
# SGD Step:  540 | Train Loss: 0.0048 | Train Acc: 0.95% | Test Loss: 0.1432 | Test Acc: 0.94%
# SGD Step:  560 | Train Loss: 0.0135 | Train Acc: 0.96% | Test Loss: 0.1143 | Test Acc: 0.95%
# SGD Step:  580 | Train Loss: 0.0018 | Train Acc: 0.96% | Test Loss: 0.1126 | Test Acc: 0.96%
# SGD Step:  600 | Train Loss: 0.0529 | Train Acc: 0.94% | Test Loss: 0.1982 | Test Acc: 0.94%
# SGD Step:  620 | Train Loss: 0.1347 | Train Acc: 0.95% | Test Loss: 0.1324 | Test Acc: 0.94%
# SGD Step:  640 | Train Loss: 0.0198 | Train Acc: 0.95% | Test Loss: 0.1495 | Test Acc: 0.93%
# SGD Step:  660 | Train Loss: 3.9753 | Train Acc: 0.96% | Test Loss: 0.1183 | Test Acc: 0.96%
# SGD Step:  680 | Train Loss: 0.0349 | Train Acc: 0.96% | Test Loss: 0.1198 | Test Acc: 0.94%
# SGD Step:  700 | Train Loss: 0.0023 | Train Acc: 0.96% | Test Loss: 0.1127 | Test Acc: 0.96%
# SGD Step:  720 | Train Loss: 0.0019 | Train Acc: 0.96% | Test Loss: 0.1164 | Test Acc: 0.95%
# SGD Step:  740 | Train Loss: 0.0649 | Train Acc: 0.96% | Test Loss: 0.1109 | Test Acc: 0.96%
# SGD Step:  760 | Train Loss: 0.0034 | Train Acc: 0.94% | Test Loss: 0.1730 | Test Acc: 0.93%
# SGD Step:  780 | Train Loss: 0.0006 | Train Acc: 0.94% | Test Loss: 0.1544 | Test Acc: 0.94%
# SGD Step:  800 | Train Loss: 0.0053 | Train Acc: 0.97% | Test Loss: 0.1046 | Test Acc: 0.96%
# SGD Step:  820 | Train Loss: 0.0500 | Train Acc: 0.97% | Test Loss: 0.1012 | Test Acc: 0.95%
# SGD Step:  840 | Train Loss: 0.0023 | Train Acc: 0.97% | Test Loss: 0.1049 | Test Acc: 0.94%
# SGD Step:  860 | Train Loss: 0.0224 | Train Acc: 0.97% | Test Loss: 0.0867 | Test Acc: 0.97%
# SGD Step:  880 | Train Loss: 0.0041 | Train Acc: 0.98% | Test Loss: 0.0858 | Test Acc: 0.98%
# SGD Step:  900 | Train Loss: 0.0165 | Train Acc: 0.98% | Test Loss: 0.0909 | Test Acc: 0.96%
# SGD Step:  920 | Train Loss: 0.0022 | Train Acc: 0.98% | Test Loss: 0.0831 | Test Acc: 0.98%
# SGD Step:  940 | Train Loss: 0.2650 | Train Acc: 0.98% | Test Loss: 0.0871 | Test Acc: 0.96%
# SGD Step:  960 | Train Loss: 0.1444 | Train Acc: 0.98% | Test Loss: 0.0846 | Test Acc: 0.98%
# SGD Step:  980 | Train Loss: 0.0268 | Train Acc: 0.98% | Test Loss: 0.0813 | Test Acc: 0.98%
# SGD Step:  999 | Train Loss: 0.0074 | Train Acc: 0.95% | Test Loss: 0.1231 | Test Acc: 0.94%
